# %% [markdown]
# LOAN PREDICTION

# %%
import warnings
from pandas import Series, DataFrame
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
data = pd.read_csv("/content/LOAN-DATASET.csv")
data_clean = data.dropna()
print(data_clean)
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        2           0          1              2
# 1    LP001003       1        1           1          1              2
# 2    LP001005       1        1           0          1              1
# 3    LP001006       1        1           0          2              2
# 4    LP001008       1        2           0          1              2
# ..        ...     ...      ...         ...        ...            ...
# 604  LP002978       2        2           0          1              2
# 605  LP002979       1        1           3          1              2
# 606  LP002983       1        1           1          1              2
# 607  LP002984       1        1           2          1              2
# 608  LP002990       2        2           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#selected columns
predvar = data_clean[['Gender','Married','Dependents','Education', 'Self_Employed','Credit_History','Property_Area']]
target = data_clean.Loan_Status
predictors = predvar.copy()
#data converted to float required for calculation
predictors = predictors.astype(np.float32)
# split data into train and test sets
pred_train, pred_test, tar_train, tar_test = train_test_split(predictors, target, test_size=.2, random_state=42)
X = pred_train
y = tar_train
Classification_ = DecisionTreeClassifier()
Classification_.fit(X, y)
expected = y
predicted = Classification_.predict(X)

def predictLoanEligibility(a,b):
  p = Classification_.predict(b)
  if p == 1:
    return 'Status' + a+' : Eligible for Loan'
  else:
    return 'status'+a+': Not eligible for loan'
# Testing data manually
#   loan no     data        actual result
# LP001489, 2,1,0,1,2,1,1       ,2
# LP001478, 1,2,0,1,2,1,2       ,1
# LP001482, 1,1,0,1,1,1,2       ,1
# LP001488, 1,1,3,1,2,1,2      ,2
# LP001487, 1,2,0,1,2,1,2      ,1

# enter the loan no
loan_no = 'LP001492'
# the data to be predicted
person_stats=[[1,2,1,1,2,1,2]]

print('First 5 row of complete dataset')
print(data.head())
print("::::::::::::::::::::::::::::::::::::::::::::::::::::")
print(predvar.head())
print('::::::::::::::::::::::::::::::::::::::::::::::::::::')
print('::::::::::::::::::::::::::::::::::::::::::::::::::::')
print('RESULTS..')
print ('Decision Tree Classifier Accuracy:', Classification_.score(pred_test, tar_test) * 100, '%')
print(predictLoanEligibility(loan_no,person_stats))
# Out:
# First 5 row of complete dataset
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        2           0          1              2
# 1  LP001003       1        1           1          1              2
# 2  LP001005       1        1           0          1              1
# 3  LP001006       1        1           0          2              2
# 4  LP001008       1        2           0          1              2
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0      -99999               360
# 1             4583             1508.0         128               360
# 2             3000                0.0          66               360
# 3             2583             2358.0         120               360
# 4             6000                0.0         141               360
#
#    Credit_History  Property_Area  Loan_Status
# 0               1              3            1
# ...
